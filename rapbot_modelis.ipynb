# %%
import numpy as np
import random
import os
import json
from google.colab import drive
import keras
from keras import layers

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open("/content/drive/MyDrive/rapbot_text_all.txt", "r", encoding="utf-8") as f:
    text_All = f.read()

meta = json.load(open("/content/drive/MyDrive/rapbot_char_meta.json", "r"))
chars = meta["chars"]
char_indices = meta["char_indices"]
indices_char = {int(k): v for k, v in meta["indices_char"].items()}

print("Corpus size:", len(text_All))
print("Unikalūs simboliai:", len(chars))
# Out:
# Corpus size: 1378646
# Unikalūs simboliai: 40

# %%
maxlen = 60
step = 2
max_corpus_window = 150000

def get_x_y():
    """Sukuria (X, Y) mokymo porą iš atsitiktinio teksto lango."""

    if len(text_All) <= max_corpus_window:
        text_chunk = text_All
    else:
        start_pos = random.randint(0, len(text_All) - max_corpus_window)
        end_pos = start_pos + max_corpus_window
        text_chunk = text_All[start_pos:end_pos]

    sentences = []
    next_chars = []

    for i in range(0, len(text_chunk) - maxlen, step):
        sentences.append(text_chunk[i : i + maxlen])
        next_chars.append(text_chunk[i + maxlen])

    x = np.zeros((len(sentences), maxlen, len(chars)), dtype="bool")
    y = np.zeros((len(sentences), len(chars)), dtype="bool")

    for i, sentence in enumerate(sentences):
        for t, char in enumerate(sentence):
            x[i, t, char_indices[char]] = 1
        y[i, char_indices[next_chars[i]]] = 1

    return x, y

# %%
model = keras.Sequential([
    keras.Input(shape=(maxlen, len(chars))),
    layers.LSTM(128, dropout=0.2, recurrent_dropout=0.2),
    layers.Dense(len(chars), activation="softmax")
])

optimizer = keras.optimizers.RMSprop(learning_rate=0.003, clipnorm=1.0)
model.compile(loss="categorical_crossentropy", optimizer=optimizer)

model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_13 (LSTM)                  │ (None, 128)            │        86,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 40)             │         5,160 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 91,688 (358.16 KB)
#  Trainable params: 91,688 (358.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 60
batch_size = 128

model_path = "/content/drive/MyDrive/rap_lyrics_lstm_v3.keras"

print("\n--- Pradedamas treniravimas ---")

for epoch in range(epochs):
    print(f"\nEpocha {epoch+1}/{epochs}")

    x, y = get_x_y()   # atsitiktinis 500k simbolių gabalas
    model.fit(x, y, batch_size=batch_size, epochs=1)

    # Išsaugome modelį Drive
    model.save(model_path)
    print("Modelis išsaugotas:", model_path)
# Out:
# --- Pradedamas treniravimas ---
#
# Epocha 1/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 98s 165ms/step - loss: 1.7570
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 2/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 98s 168ms/step - loss: 1.7514
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 3/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 166ms/step - loss: 1.7872
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 4/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 96s 163ms/step - loss: 1.6763
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 5/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 166ms/step - loss: 1.7210
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 6/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 96s 163ms/step - loss: 1.7357
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 7/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 165ms/step - loss: 1.7010
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 8/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 166ms/step - loss: 1.7239
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 9/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 95s 163ms/step - loss: 1.7108
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 10/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 166ms/step - loss: 1.7239
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 11/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 95s 163ms/step - loss: 1.7104
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 12/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 95s 163ms/step - loss: 1.7857
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 13/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 95s 163ms/step - loss: 1.6880
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 14/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 166ms/step - loss: 1.7254
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 15/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 165ms/step - loss: 1.7593
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 16/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 96s 164ms/step - loss: 1.7076
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 17/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 96s 163ms/step - loss: 1.6989
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 18/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 98s 167ms/step - loss: 1.6768
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 19/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 165ms/step - loss: 1.7231
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 20/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 165ms/step - loss: 1.6869
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 21/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 98s 167ms/step - loss: 1.6875
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 22/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 96s 164ms/step - loss: 1.6515
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 23/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 165ms/step - loss: 1.6921
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 24/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 165ms/step - loss: 1.7005
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 25/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 96s 164ms/step - loss: 1.6952
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 26/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 98s 167ms/step - loss: 1.6816
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 27/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 95s 162ms/step - loss: 1.6637
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 28/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 96s 163ms/step - loss: 1.7098
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 29/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 96s 164ms/step - loss: 1.6828
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 30/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 166ms/step - loss: 1.6544
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 31/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 95s 163ms/step - loss: 1.6546
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 32/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 166ms/step - loss: 1.6538
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 33/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 166ms/step - loss: 1.7108
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 34/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 96s 163ms/step - loss: 1.6725
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 35/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 96s 164ms/step - loss: 1.6485
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 36/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 96s 164ms/step - loss: 1.6703
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 37/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 98s 167ms/step - loss: 1.6247
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 38/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 98s 167ms/step - loss: 1.6912
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 39/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 96s 163ms/step - loss: 1.6860
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 40/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 98s 166ms/step - loss: 1.6537
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 41/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 100s 170ms/step - loss: 1.6697
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 42/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 165ms/step - loss: 1.7941
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 43/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 98s 167ms/step - loss: 1.6335
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 44/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 101s 171ms/step - loss: 1.6346
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 45/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 98s 167ms/step - loss: 1.7599
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 46/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 99s 169ms/step - loss: 1.6575
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 47/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 98s 167ms/step - loss: 1.6380
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 48/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 165ms/step - loss: 1.7149
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 49/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 166ms/step - loss: 1.7014
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 50/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 99s 168ms/step - loss: 1.6707
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 51/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 165ms/step - loss: 1.6503
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 52/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 165ms/step - loss: 1.6689
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 53/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 98s 168ms/step - loss: 1.6590
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 54/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 165ms/step - loss: 1.6523
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 55/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 166ms/step - loss: 1.6433
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 56/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 97s 166ms/step - loss: 1.6619
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 57/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 98s 167ms/step - loss: 1.6774
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 58/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 96s 164ms/step - loss: 1.7584
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 59/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 96s 164ms/step - loss: 1.6410
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
#
# Epocha 60/60
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 98s 166ms/step - loss: 1.7043
# Modelis išsaugotas: /content/drive/MyDrive/rap_lyrics_lstm_v3.keras
